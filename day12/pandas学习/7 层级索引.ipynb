# %% [markdown]
# # 7 层级索引（hierarchical indexing）（机器学习，深度学习不重要）

# %%
import pandas as pd
import numpy as np

#MultiIndex是层级索引，索引类型的一种
index1 = pd.MultiIndex.from_arrays([['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c', 'd', 'd', 'd'],
                [0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2]], names=['cloth', 'size'])

ser_obj = pd.Series(np.random.randn(12),index=index1)
print(ser_obj)
print(type(ser_obj)) #Series
print(type(ser_obj.index)) #索引类型，MultiIndex
print(ser_obj.index)
print(ser_obj.index.levels) #层级索引的索引值
ser_obj.index.codes  #没那么重要，代表索引的位置
# Out:
# cloth  size
# a      0       0.941703
#        1      -0.682929
#        2      -0.372908
# b      0       0.468731
#        1       0.038660
#        2       1.389067
# c      0      -1.070068
#        1       0.792871
#        2      -0.637087
# d      0       0.148498
#        1       0.032267
#        2      -0.335607
# dtype: float64
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.indexes.multi.MultiIndex'>
# MultiIndex([('a', 0),
#             ('a', 1),
#             ('a', 2),
#             ('b', 0),
#             ('b', 1),
#             ('b', 2),
#             ('c', 0),
#             ('c', 1),
#             ('c', 2),
#             ('d', 0),
#             ('d', 1),
#             ('d', 2)],
#            names=['cloth', 'size'])
# [['a', 'b', 'c', 'd'], [0, 1, 2]]
# FrozenList([[0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3], [0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
ser_obj
# Out:
# cloth  size
# a      0       0.941703
#        1      -0.682929
#        2      -0.372908
# b      0       0.468731
#        1       0.038660
#        2       1.389067
# c      0      -1.070068
#        1       0.792871
#        2      -0.637087
# d      0       0.148498
#        1       0.032267
#        2      -0.335607
# dtype: float64

# %%
#层级索引如何取数据
print('-'*50)
print(ser_obj['c']) #取出c的所有数据，取出的是series
print('-'*50)
print(ser_obj.loc['a', 2])
print('-'*50)
print(ser_obj[:, 2]) #取出所有行的内层索引为2的数据
# Out:
# --------------------------------------------------
# size
# 0   -1.070068
# 1    0.792871
# 2   -0.637087
# dtype: float64
# --------------------------------------------------
# -0.3729084798387157
# --------------------------------------------------
# cloth
# a   -0.372908
# b    1.389067
# c   -0.637087
# d   -0.335607
# dtype: float64

# %% [markdown]
# ## 交换层级

# %%
print(ser_obj.swaplevel())
print('-'*50)
print(ser_obj)
print('-'*50)
ser_obj=ser_obj.swaplevel()
print(ser_obj)
# Out:
# size  cloth
# 0     a        0.941703
# 1     a       -0.682929
# 2     a       -0.372908
# 0     b        0.468731
# 1     b        0.038660
# 2     b        1.389067
# 0     c       -1.070068
# 1     c        0.792871
# 2     c       -0.637087
# 0     d        0.148498
# 1     d        0.032267
# 2     d       -0.335607
# dtype: float64
# --------------------------------------------------
# cloth  size
# a      0       0.941703
#        1      -0.682929
#        2      -0.372908
# b      0       0.468731
#        1       0.038660
#        2       1.389067
# c      0      -1.070068
#        1       0.792871
#        2      -0.637087
# d      0       0.148498
#        1       0.032267
#        2      -0.335607
# dtype: float64
# --------------------------------------------------
# size  cloth
# 0     a        0.941703
# 1     a       -0.682929
# 2     a       -0.372908
# 0     b        0.468731
# 1     b        0.038660
# 2     b        1.389067
# 0     c       -1.070068
# 1     c        0.792871
# 2     c       -0.637087
# 0     d        0.148498
# 1     d        0.032267
# 2     d       -0.335607
# dtype: float64

# %%
print(ser_obj.sort_index(level=0))  #层级索引按那个索引级别排序,level=0表示按最外层索引排序
# Out:
# size  cloth
# 0     a        0.941703
#       b        0.468731
#       c       -1.070068
#       d        0.148498
# 1     a       -0.682929
#       b        0.038660
#       c        0.792871
#       d        0.032267
# 2     a       -0.372908
#       b        1.389067
#       c       -0.637087
#       d       -0.335607
# dtype: float64

# %%
ser_obj
# Out:
# size  cloth
# 0     a        0.941703
# 1     a       -0.682929
# 2     a       -0.372908
# 0     b        0.468731
# 1     b        0.038660
# 2     b        1.389067
# 0     c       -1.070068
# 1     c        0.792871
# 2     c       -0.637087
# 0     d        0.148498
# 1     d        0.032267
# 2     d       -0.335607
# dtype: float64

# %%
#把最大索引变为列索引
df_obj=ser_obj.unstack()  #unstack的level参数是索引层级
print(df_obj)
# Out:
# cloth         a         b         c         d
# size
# 0      0.941703  0.468731 -1.070068  0.148498
# 1     -0.682929  0.038660  0.792871  0.032267
# 2     -0.372908  1.389067 -0.637087 -0.335607

# %%
print(df_obj)
#对df进行stack，就会把行，列索引进行堆叠，变为series
#把列索引放入内层,只能放到内层
print(df_obj.stack())  #stack变为series和unstack保持一致的
# df_obj=df_obj.transpose()
# Out:
# cloth         a         b         c         d
# size
# 0      0.941703  0.468731 -1.070068  0.148498
# 1     -0.682929  0.038660  0.792871  0.032267
# 2     -0.372908  1.389067 -0.637087 -0.335607
# size  cloth
# 0     a        0.941703
#       b        0.468731
#       c       -1.070068
#       d        0.148498
# 1     a       -0.682929
#       b        0.038660
#       c        0.792871
#       d        0.032267
# 2     a       -0.372908
#       b        1.389067
#       c       -0.637087
#       d       -0.335607
# dtype: float64
